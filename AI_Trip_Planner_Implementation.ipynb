# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from crewai import LLM
from langchain_ollama.llms import OllamaLLM

llm = LLM(
    model="ollama/llama3.2",
    base_url="http://localhost:11434"
)

# %%
from crewai.tools import tool
from langchain_community.tools import DuckDuckGoSearchResults 
import json


@tool
def search_web_tool(query: str):
    """
    Searches the web and returns results.
    """
    search_tool = DuckDuckGoSearchResults(num_results=10, verbose=True)
    return search_tool.run(query)

# %%
from crewai import Agent

# Agent Resercher
guide_expert= Agent( 
    role="City Local Guide Expert",
    goal="Provides information on things to do in the city based on the user's interests.",
    backstory="""A local expert with a passion for sharing the best experiences and hidden gems of their city.""",
    tools=[search_web_tool],
    verbose=True,
    max_iter=5,
    llm=LLM(model="ollama/llama3.2",base_url="http://localhost:11434"),  #ChatOpenAI(temperature=0, model="gpt-4o-mini"),
    allow_delegation=False,
    )

# %%
# Agent city expert
location_expert = Agent(
    role="Travel Trip Expert",
    goal="Adapt to the user destination vity language (French if city in French Country. Gather helpful information about to the city and city during travel.",
    backstory="""A seasoned traveler who has explored various destinations and knows the ins and outs of travel logistics.""",
    tools=[search_web_tool],
    verbose=True,
    max_iter=5,
    llm=LLM(model="ollama/llama3.2",base_url="http://localhost:11434"),
    allow_delegation=False,
    )

# %%
planner_expert = Agent(
    role="Travel Planning Expert",
    goal="Compiles all gathered information to provide a comprehensive travel plan.",
    backstory="""
    You are a professional guide with a passion for travel.
    An organizational wizard who can turn a list of possibilities into a seamless itinerary.
    """,
    tools=[search_web_tool],
    verbose=True,
    max_iter=5,
    llm=LLM(model="ollama/llama3.2",base_url="http://localhost:11434"),
    allow_delegation=False,
    )

# %%
from datetime import datetime
from crewai import Task

from_city = "India"
destination_city = "Rome"
date_from = "1st March 2025"
date_to = "7th March 2025"
interests = "sight seeing and good food"

location_task = Task(
    description=f"""
    In French : This task involves a comprehensive data collection process to provide the traveler with essential information about their destination. It includes researching and compiling details on various accommodations, ranging from budget-friendly hostels to luxury hotels, as well as estimating the cost of living in the area. The task also covers transportation options, visa requirements, and any travel advisories that may be relevant.
    consider also the weather conditions forcast on the travel dates. and all the events that may be relevant to the traveler during the trip period.
    
    Traveling from : {from_city}
    Destination city : {destination_city}
    Arrival Date : {date_from}
    Departure Date : {date_to}

    Follow this rules : 
    1. if the {destination_city} is in a French country : Respond in FRENCH.
    """,
    expected_output=f"""
    if the {destination_city} is in a French country : Respond in FRENCH.
    In markdown format : A detailed markdown report that includes a curated list of recommended places to stay, a breakdown of daily living expenses, and practical travel tips to ensure a smooth journey.
    """,
    agent=location_expert,
    output_file='city_report.md',
)

# %%
guide_task = Task(
    description=f"""
    if the {destination_city} is in a French country : Respond in FRENCH.
    Tailored to the traveler's personal {interests}, this task focuses on creating an engaging and informative guide to the city's attractions. It involves identifying cultural landmarks, historical spots, entertainment venues, dining experiences, and outdoor activities that align with the user's preferences such {interests}. The guide also highlights seasonal events and festivals that might be of interest during the traveler's visit.
    Destination city : {destination_city}
    interests : {interests}
    Arrival Date : {date_from}
    Departure Date : {date_to}

    Follow this rules : 
    1. if the {destination_city} is in a French country : Respond in FRENCH.
    """,
    expected_output=f"""
    An interactive markdown report that presents a personalized itinerary of activities and attractions, complete with descriptions, locations, and any necessary reservations or tickets.
    """,

    agent=guide_expert,
    output_file='guide_report.md',
)

# %%
planner_task = Task(
    description=f"""
    This task synthesizes all collected information into a detaileds introduction to the city (description of city and presentation, in 3 pragraphes) cohesive and practical travel plan. and takes into account the traveler's schedule, preferences, and budget to draft a day-by-day itinerary. The planner also provides insights into the city's layout and transportation system to facilitate easy navigation.
    Destination city : {destination_city}
    interests : {interests}
    Arrival Date : {date_from}
    Departure Date : {date_to}

    Follow this rules : 
    1. if the {destination_city} is in a French country : Respond in FRENCH.
    """,
    expected_output="""
    if the {destination_city} is in a French country : Respond in FRENCH.
    A rich markdown document with emojis on each title and subtitle, that :
    In markdown format : 
    # Welcome to {destination_city} :
    A 4 paragraphes markdown formated including :
    - a curated articles of presentation of the city, 
    - a breakdown of daily living expenses, and spots to visit.
    # Here's your Travel Plan to {destination_city} :
    Outlines a daily detailed travel plan list with time allocations and details for each activity, along with an overview of the city's highlights based on the guide's recommendations
    """,
    context=[location_task, guide_task],
    #context=context,
    agent=planner_expert,
        output_file='travel_plan.md',
        )

# %%
# Task: Location
def location_task(agent, from_city, destination_city, date_from, date_to):
    return Task(
        description=f"""
        In French : This task involves a comprehensive data collection process to provide the traveler with essential information about their destination. It includes researching and compiling details on various accommodations, ranging from budget-friendly hostels to luxury hotels, as well as estimating the cost of living in the area. The task also covers transportation options, visa requirements, and any travel advisories that may be relevant.
        consider also the weather conditions forcast on the travel dates. and all the events that may be relevant to the traveler during the trip period.
        
        Traveling from : {from_city}
        Destination city : {destination_city}
        Arrival Date : {date_from}
        Departure Date : {date_to}

        Follow this rules : 
        1. if the {destination_city} is in a French country : Respond in FRENCH.
        """,
        expected_output=f"""
        if the {destination_city} is in a French country : Respond in FRENCH.
        In markdown format : A detailed markdown report that includes a curated list of recommended places to stay, a breakdown of daily living expenses, and practical travel tips to ensure a smooth journey.
        """,
        agent=agent,
        output_file='city_report.md',
    )

# Task: Location
def guide_task(agent, destination_city, interests, date_from, date_to):    
    return Task(
        description=f"""
        if the {destination_city} is in a French country : Respond in FRENCH.
        Tailored to the traveler's personal {interests}, this task focuses on creating an engaging and informative guide to the city's attractions. It involves identifying cultural landmarks, historical spots, entertainment venues, dining experiences, and outdoor activities that align with the user's preferences such {interests}. The guide also highlights seasonal events and festivals that might be of interest during the traveler's visit.
        Destination city : {destination_city}
        interests : {interests}
        Arrival Date : {date_from}
        Departure Date : {date_to}

        Follow this rules : 
        1. if the {destination_city} is in a French country : Respond in FRENCH.
        """,
        expected_output=f"""
        An interactive markdown report that presents a personalized itinerary of activities and attractions, complete with descriptions, locations, and any necessary reservations or tickets.
        """,

        agent=agent,
        output_file='guide_report.md',
    )


# Task: Planner
def planner_task(context, agent, destination_city, interests, date_from, date_to):
    return Task(
        description=f"""
        This task synthesizes all collected information into a detaileds introduction to the city (description of city and presentation, in 3 pragraphes) cohesive and practical travel plan. and takes into account the traveler's schedule, preferences, and budget to draft a day-by-day itinerary. The planner also provides insights into the city's layout and transportation system to facilitate easy navigation.
        Destination city : {destination_city}
        interests : {interests}
        Arrival Date : {date_from}
        Departure Date : {date_to}

        Follow this rules : 
        1. if the {destination_city} is in a French country : Respond in FRENCH.
        """,
        expected_output="""
        if the {destination_city} is in a French country : Respond in FRENCH.
        A rich markdown document with emojis on each title and subtitle, that :
        In markdown format : 
        # Welcome to {destination_city} :
        A 4 paragraphes markdown formated including :
        - a curated articles of presentation of the city, 
        - a breakdown of daily living expenses, and spots to visit.
        # Here's your Travel Plan to {destination_city} :
        Outlines a daily detailed travel plan list with time allocations and details for each activity, along with an overview of the city's highlights based on the guide's recommendations
        """,
        #context=[location_task, guide_task],
        context=context,
        agent=agent,
        output_file='travel_plan.md',
        )

# %%
location_task = location_task(
  location_expert,
  from_city,
  destination_city,
  date_from,
  date_to
)

guide_task = guide_task(
  guide_expert,
  destination_city,
  interests,
  date_from,
  date_to
)

planner_task = planner_task(
  [location_task, guide_task],
  planner_expert,
  destination_city,
  interests,
  date_from,
  date_to,
)

# %%
# import sys
# sys.setrecursionlimit(5000)

# %%
from crewai import Crew, Process
crew = Crew(
agents=[location_expert, guide_expert, planner_expert],
tasks=[location_task, guide_task, planner_task],
# process=Process.sequential,
# full_output=True,
# share_crew=False,
# verbose=True
)

result = crew.kickoff()
# Out:
# # Agent: Travel Trip Expert
# ## Task:
#         In French : This task involves a comprehensive data collection process to provide the traveler with essential information about their destination. It includes researching and compiling details on various accommodations, ranging from budget-friendly hostels to luxury hotels, as well as estimating the cost of living in the area. The task also covers transportation options, visa requirements, and any travel advisories that may be relevant.
#         consider also the weather conditions forcast on the travel dates. and all the events that may be relevant to the traveler during the trip period.
#
#         Traveling from : India
#         Destination city : Rome
#         Arrival Date : 1st March 2025
#         Departure Date : 7th March 2025
#
#         Follow this rules :
#         1. if the Rome is in a French country : Respond in FRENCH.
#
#
#
#
#
#
#
#
#
#  An unknown error occurred. Please check the details below.
# ---------------------------------------------------------------------------
# ConnectError                              Traceback (most recent call last)
# File ~/anaconda3/envs/Gen_AI/lib/python3.10/site-packages/httpx/_transports/default.py:101, in map_httpcore_exceptions()
#     100 try:
# --> 101     yield
#     102 except Exception as exc:
#
# File ~/anaconda3/envs/Gen_AI/lib/python3.10/site-packages/httpx/_transports/default.py:250, in HTTPTransport.handle_request(self, request)
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#
# File ~/anaconda3/envs/Gen_AI/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#
# File ~/anaconda3/envs/Gen_AI/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#
# File ~/anaconda3/envs/Gen_AI/lib/python3.10/site-packages/httpcore/_sync/connection.py:101, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
# --> 101     raise exc
#     103 return self._connection.handle_request(request)
#
# File ~/anaconda3/envs/Gen_AI/lib/python3.10/site-packages/httpcore/_sync/connection.py:78, in HTTPConnection.handle_request(self, request)
#      77 if self._connection is None:
# ---> 78     stream = self._connect(request)
#      80     ssl_object = stream.get_extra_info("ssl_object")
#
# File ~/anaconda3/envs/Gen_AI/lib/python3.10/site-packages/httpcore/_sync/connection.py:124, in HTTPConnection._connect(self, request)
#     123 with Trace("connect_tcp", logger, request, kwargs) as trace:
# --> 124     stream = self._network_backend.connect_tcp(**kwargs)
#     125     trace.return_value = stream
#
# File ~/anaconda3/envs/Gen_AI/lib/python3.10/site-packages/httpcore/_backends/sync.py:207, in SyncBackend.connect_tcp(self, host, port, timeout, local_address, socket_options)
#     202 exc_map: ExceptionMapping = {
#     203     socket.timeout: ConnectTimeout,
#     204     OSError: ConnectError,
#     205 }
# --> 207 with map_exceptions(exc_map):
#     208     sock = socket.create_connection(
#     209         address,
#     210         timeout,
#     211         source_address=source_address,
#     212     )
#
# File ~/anaconda3/envs/Gen_AI/lib/python3.10/contextlib.py:153, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     152 try:
# --> 153     self.gen.throw(typ, value, traceback)
#     154 except StopIteration as exc:
#     155     # Suppress StopIteration *unless* it's the same exception that
#     156     # was passed to throw().  This prevents a StopIteration
#     157     # raised inside the "with" statement from being suppressed.
#
# File ~/anaconda3/envs/Gen_AI/lib/python3.10/site-packages/httpcore/_exceptions.py:14, in map_exceptions(map)
#      13     if isinstance(exc, from_exc):
# ---> 14         raise to_exc(exc) from exc
#      15 raise
#
# ConnectError: [Errno 111] Connection refused
#
# The above exception was the direct cause of the following exception:
#
# ConnectError                              Traceback (most recent call last)
# File ~/anaconda3/envs/Gen_AI/lib/python3.10/site-packages/litellm/llms/custom_httpx/llm_http_handler.py:159, in BaseLLMHTTPHandler._make_common_sync_call(self, sync_httpx_client, provider_config, api_base, headers, data, timeout, litellm_params, logging_obj, stream, signed_json_body)
#     158 try:
# --> 159     response = sync_httpx_client.post(
#     160         url=api_base,
#     161         headers=headers,
#     162         data=(
#     163             signed_json_body
#     164             if signed_json_body is not None
#     165             else json.dumps(data)
#     166         ),
#     167         timeout=timeout,
#     168         stream=stream,
#     169         logging_obj=logging_obj,
#     170     )
#     171 except httpx.HTTPStatusError as e:
#
# File ~/anaconda3/envs/Gen_AI/lib/python3.10/site-packages/litellm/llms/custom_httpx/http_handler.py:706, in HTTPHandler.post(self, url, data, json, params, headers, stream, timeout, files, content, logging_obj)
#     705 except Exception as e:
# --> 706     raise e
#
# File ~/anaconda3/envs/Gen_AI/lib/python3.10/site-packages/litellm/llms/custom_httpx/http_handler.py:685, in HTTPHandler.post(self, url, data, json, params, headers, stream, timeout, files, content, logging_obj)
#     682     req = self.client.build_request(
#     683         "POST", url, data=data, json=json, params=params, headers=headers, files=files, content=content  # type: ignore
#     684     )
# --> 685 response = self.client.send(req, stream=stream)
#     686 response.raise_for_status()
#
# File ~/anaconda3/envs/Gen_AI/lib/python3.10/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#
# File ~/anaconda3/envs/Gen_AI/lib/python3.10/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#
# File ~/anaconda3/envs/Gen_AI/lib/python3.10/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#
# File ~/anaconda3/envs/Gen_AI/lib/python3.10/site-packages/httpx/_client.py:1014, in Client._send_single_request(self, request)
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#
# File ~/anaconda3/envs/Gen_AI/lib/python3.10/site-packages/httpx/_transports/default.py:249, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)
#     247     extensions=request.extensions,
#     248 )
# --> 249 with map_httpcore_exceptions():
#     250     resp = self._pool.handle_request(req)
#
# File ~/anaconda3/envs/Gen_AI/lib/python3.10/contextlib.py:153, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     152 try:
# --> 153     self.gen.throw(typ, value, traceback)
#     154 except StopIteration as exc:
#     155     # Suppress StopIteration *unless* it's the same exception that
#     156     # was passed to throw().  This prevents a StopIteration
#     157     # raised inside the "with" statement from being suppressed.
#
# File ~/anaconda3/envs/Gen_AI/lib/python3.10/site-packages/httpx/_transports/default.py:118, in map_httpcore_exceptions()
#     117 message = str(exc)
# --> 118 raise mapped_exc(message) from exc
#
# ConnectError: [Errno 111] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# OllamaError                               Traceback (most recent call last)
# File ~/anaconda3/envs/Gen_AI/lib/python3.10/site-packages/litellm/main.py:2928, in completion(model, messages, timeout, temperature, top_p, n, stream, stream_options, stop, max_completion_tokens, max_tokens, modalities, prediction, audio, presence_penalty, frequency_penalty, logit_bias, user, reasoning_effort, response_format, seed, tools, tool_choice, logprobs, top_logprobs, parallel_tool_calls, web_search_options, deployment_id, extra_headers, functions, function_call, base_url, api_version, api_key, model_list, thinking, **kwargs)
#    2922     api_base = (
#    2923         litellm.api_base
#    2924         or api_base
#    2925         or get_secret("OLLAMA_API_BASE")
#    2926         or "http://localhost:11434"
#    2927     )
# -> 2928     response = base_llm_http_handler.completion(
#    2929         model=model,
#    2930         stream=stream,
#    2931         messages=messages,
#    2932         acompletion=acompletion,
#    2933         api_base=api_base,
#    2934         model_response=model_response,
#    2935         optional_params=optional_params,
#    2936         litellm_params=litellm_params,
#    2937         custom_llm_provider="ollama",
#    2938         timeout=timeout,
#    2939         headers=headers,
#    2940         encoding=encoding,
#    2941         api_key=api_key,
#    2942         logging_obj=logging,  # model call logging done inside the class as we make need to modify I/O to fit aleph alpha's requirements
#    2943         client=client,
#    2944     )
#    2946 elif custom_llm_provider == "ollama_chat":
#
# File ~/anaconda3/envs/Gen_AI/lib/python3.10/site-packages/litellm/llms/custom_httpx/llm_http_handler.py:454, in BaseLLMHTTPHandler.completion(self, model, messages, api_base, custom_llm_provider, model_response, encoding, logging_obj, optional_params, timeout, litellm_params, acompletion, stream, fake_stream, api_key, headers, client, provider_config)
#     452     sync_httpx_client = client
# --> 454 response = self._make_common_sync_call(
#     455     sync_httpx_client=sync_httpx_client,
#     456     provider_config=provider_config,
#     457     api_base=api_base,
#     458     headers=headers,
#     459     data=data,
#     460     signed_json_body=signed_json_body,
#     461     timeout=timeout,
#     462     litellm_params=litellm_params,
#     463     logging_obj=logging_obj,
#     464 )
#     465 return provider_config.transform_response(
#     466     model=model,
#     467     raw_response=response,
#    (...)
#     476     json_mode=json_mode,
#     477 )
#
# File ~/anaconda3/envs/Gen_AI/lib/python3.10/site-packages/litellm/llms/custom_httpx/llm_http_handler.py:186, in BaseLLMHTTPHandler._make_common_sync_call(self, sync_httpx_client, provider_config, api_base, headers, data, timeout, litellm_params, logging_obj, stream, signed_json_body)
#     185 except Exception as e:
# --> 186     raise self._handle_error(e=e, provider_config=provider_config)
#     187 break
#
# File ~/anaconda3/envs/Gen_AI/lib/python3.10/site-packages/litellm/llms/custom_httpx/llm_http_handler.py:2058, in BaseLLMHTTPHandler._handle_error(self, e, provider_config)
#    2056     error_headers = {}
# -> 2058 raise provider_config.get_error_class(
#    2059     error_message=error_text,
#    2060     status_code=status_code,
#    2061     headers=error_headers,
#    2062 )
#
# OllamaError: [Errno 111] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# APIConnectionError                        Traceback (most recent call last)
# Cell In[36], line 11
#       1 from crewai import Crew, Process
#       2 crew = Crew(
#       3 agents=[location_expert, guide_expert, planner_expert],
#       4 tasks=[location_task, guide_task, planner_task],
#    (...)
#       8 # verbose=True
#       9 )
# ---> 11 result = crew.kickoff()
#
# File ~/anaconda3/envs/Gen_AI/lib/python3.10/site-packages/crewai/crew.py:659, in Crew.kickoff(self, inputs)
#     656     self._handle_crew_planning()
#     658 if self.process == Process.sequential:
# --> 659     result = self._run_sequential_process()
#     660 elif self.process == Process.hierarchical:
#     661     result = self._run_hierarchical_process()
#
# File ~/anaconda3/envs/Gen_AI/lib/python3.10/site-packages/crewai/crew.py:768, in Crew._run_sequential_process(self)
#     766 def _run_sequential_process(self) -> CrewOutput:
#     767     """Executes tasks sequentially and returns the final output."""
# --> 768     return self._execute_tasks(self.tasks)
#
# File ~/anaconda3/envs/Gen_AI/lib/python3.10/site-packages/crewai/crew.py:871, in Crew._execute_tasks(self, tasks, start_index, was_replayed)
#     868     futures.clear()
#     870 context = self._get_context(task, task_outputs)
# --> 871 task_output = task.execute_sync(
#     872     agent=agent_to_use,
#     873     context=context,
#     874     tools=cast(List[BaseTool], tools_for_task),
#     875 )
#     876 task_outputs.append(task_output)
#     877 self._process_task_result(task, task_output)
#
# File ~/anaconda3/envs/Gen_AI/lib/python3.10/site-packages/crewai/task.py:351, in Task.execute_sync(self, agent, context, tools)
#     344 def execute_sync(
#     345     self,
#     346     agent: Optional[BaseAgent] = None,
#     347     context: Optional[str] = None,
#     348     tools: Optional[List[BaseTool]] = None,
#     349 ) -> TaskOutput:
#     350     """Execute the task synchronously."""
# --> 351     return self._execute_core(agent, context, tools)
#
# File ~/anaconda3/envs/Gen_AI/lib/python3.10/site-packages/crewai/task.py:499, in Task._execute_core(self, agent, context, tools)
#     497 self.end_time = datetime.datetime.now()
#     498 crewai_event_bus.emit(self, TaskFailedEvent(error=str(e), task=self))
# --> 499 raise e
#
# File ~/anaconda3/envs/Gen_AI/lib/python3.10/site-packages/crewai/task.py:415, in Task._execute_core(self, agent, context, tools)
#     413 self.processed_by_agents.add(agent.role)
#     414 crewai_event_bus.emit(self, TaskStartedEvent(context=context, task=self))
# --> 415 result = agent.execute_task(
#     416     task=self,
#     417     context=context,
#     418     tools=tools,
#     419 )
#     421 pydantic_output, json_output = self._export_output(result)
#     422 task_output = TaskOutput(
#     423     name=self.name,
#     424     description=self.description,
#    (...)
#     430     output_format=self._get_output_format(),
#     431 )
#
# File ~/anaconda3/envs/Gen_AI/lib/python3.10/site-packages/crewai/agent.py:435, in Agent.execute_task(self, task, context, tools)
#     425 if e.__class__.__module__.startswith("litellm"):
#     426     # Do not retry on litellm errors
#     427     crewai_event_bus.emit(
#     428         self,
#     429         event=AgentExecutionErrorEvent(
#    (...)
#     433         ),
#     434     )
# --> 435     raise e
#     436 self._times_executed += 1
#     437 if self._times_executed > self.max_retry_limit:
#
# File ~/anaconda3/envs/Gen_AI/lib/python3.10/site-packages/crewai/agent.py:411, in Agent.execute_task(self, task, context, tools)
#     407         result = self._execute_with_timeout(
#     408             task_prompt, task, self.max_execution_time
#     409         )
#     410     else:
# --> 411         result = self._execute_without_timeout(task_prompt, task)
#     413 except TimeoutError as e:
#     414     # Propagate TimeoutError without retry
#     415     crewai_event_bus.emit(
#     416         self,
#     417         event=AgentExecutionErrorEvent(
#    (...)
#     421         ),
#     422     )
#
# File ~/anaconda3/envs/Gen_AI/lib/python3.10/site-packages/crewai/agent.py:507, in Agent._execute_without_timeout(self, task_prompt, task)
#     497 def _execute_without_timeout(self, task_prompt: str, task: Task) -> str:
#     498     """Execute a task without a timeout.
#     499
#     500     Args:
#    (...)
#     505         The output of the agent.
#     506     """
# --> 507     return self.agent_executor.invoke(
#     508         {
#     509             "input": task_prompt,
#     510             "tool_names": self.agent_executor.tools_names,
#     511             "tools": self.agent_executor.tools_description,
#     512             "ask_for_human_input": task.human_input,
#     513         }
#     514     )["output"]
#
# File ~/anaconda3/envs/Gen_AI/lib/python3.10/site-packages/crewai/agents/crew_agent_executor.py:121, in CrewAgentExecutor.invoke(self, inputs)
#     118 handle_unknown_error(self._printer, e)
#     119 if e.__class__.__module__.startswith("litellm"):
#     120     # Do not retry on litellm errors
# --> 121     raise e
#     122 else:
#     123     raise e
#
# File ~/anaconda3/envs/Gen_AI/lib/python3.10/site-packages/crewai/agents/crew_agent_executor.py:110, in CrewAgentExecutor.invoke(self, inputs)
#     107 self.ask_for_human_input = bool(inputs.get("ask_for_human_input", False))
#     109 try:
# --> 110     formatted_answer = self._invoke_loop()
#     111 except AssertionError:
#     112     self._printer.print(
#     113         content="Agent failed to reach a final answer. This is likely a bug - please report it.",
#     114         color="red",
#     115     )
#
# File ~/anaconda3/envs/Gen_AI/lib/python3.10/site-packages/crewai/agents/crew_agent_executor.py:206, in CrewAgentExecutor._invoke_loop(self)
#     203 except Exception as e:
#     204     if e.__class__.__module__.startswith("litellm"):
#     205         # Do not retry on litellm errors
# --> 206         raise e
#     207     if is_context_length_exceeded(e):
#     208         handle_context_length(
#     209             respect_context_window=self.respect_context_window,
#     210             printer=self._printer,
#    (...)
#     214             i18n=self._i18n,
#     215         )
#
# File ~/anaconda3/envs/Gen_AI/lib/python3.10/site-packages/crewai/agents/crew_agent_executor.py:153, in CrewAgentExecutor._invoke_loop(self)
#     142     formatted_answer = handle_max_iterations_exceeded(
#     143         formatted_answer,
#     144         printer=self._printer,
#    (...)
#     148         callbacks=self.callbacks,
#     149     )
#     151 enforce_rpm_limit(self.request_within_rpm_limit)
# --> 153 answer = get_llm_response(
#     154     llm=self.llm,
#     155     messages=self.messages,
#     156     callbacks=self.callbacks,
#     157     printer=self._printer,
#     158 )
#     159 formatted_answer = process_llm_response(answer, self.use_stop_words)
#     161 if isinstance(formatted_answer, AgentAction):
#     162     # Extract agent fingerprint if available
#
# File ~/anaconda3/envs/Gen_AI/lib/python3.10/site-packages/crewai/utilities/agent_utils.py:160, in get_llm_response(llm, messages, callbacks, printer)
#     155 except Exception as e:
#     156     printer.print(
#     157         content=f"Error during LLM call: {e}",
#     158         color="red",
#     159     )
# --> 160     raise e
#     161 if not answer:
#     162     printer.print(
#     163         content="Received None or empty response from LLM call.",
#     164         color="red",
#     165     )
#
# File ~/anaconda3/envs/Gen_AI/lib/python3.10/site-packages/crewai/utilities/agent_utils.py:151, in get_llm_response(llm, messages, callbacks, printer)
#     149 """Call the LLM and return the response, handling any invalid responses."""
#     150 try:
# --> 151     answer = llm.call(
#     152         messages,
#     153         callbacks=callbacks,
#     154     )
#     155 except Exception as e:
#     156     printer.print(
#     157         content=f"Error during LLM call: {e}",
#     158         color="red",
#     159     )
#
# File ~/anaconda3/envs/Gen_AI/lib/python3.10/site-packages/crewai/llm.py:956, in LLM.call(self, messages, tools, callbacks, available_functions)
#     952         return self._handle_streaming_response(
#     953             params, callbacks, available_functions
#     954         )
#     955     else:
# --> 956         return self._handle_non_streaming_response(
#     957             params, callbacks, available_functions
#     958         )
#     960 except LLMContextLengthExceededException:
#     961     # Re-raise LLMContextLengthExceededException as it should be handled
#     962     # by the CrewAgentExecutor._invoke_loop method, which can then decide
#     963     # whether to summarize the content or abort based on the respect_context_window flag
#     964     raise
#
# File ~/anaconda3/envs/Gen_AI/lib/python3.10/site-packages/crewai/llm.py:768, in LLM._handle_non_streaming_response(self, params, callbacks, available_functions)
#     762 # --- 1) Make the completion call
#     763 try:
#     764     # Attempt to make the completion call, but catch context window errors
#     765     # and convert them to our own exception type for consistent handling
#     766     # across the codebase. This allows CrewAgentExecutor to handle context
#     767     # length issues appropriately.
# --> 768     response = litellm.completion(**params)
#     769 except ContextWindowExceededError as e:
#     770     # Convert litellm's context window error to our own exception type
#     771     # for consistent handling in the rest of the codebase
#     772     raise LLMContextLengthExceededException(str(e))
#
# File ~/anaconda3/envs/Gen_AI/lib/python3.10/site-packages/litellm/utils.py:1283, in client.<locals>.wrapper(*args, **kwargs)
#    1279 if logging_obj:
#    1280     logging_obj.failure_handler(
#    1281         e, traceback_exception, start_time, end_time
#    1282     )  # DO NOT MAKE THREADED - router retry fallback relies on this!
# -> 1283 raise e
#
# File ~/anaconda3/envs/Gen_AI/lib/python3.10/site-packages/litellm/utils.py:1161, in client.<locals>.wrapper(*args, **kwargs)
#    1159         print_verbose(f"Error while checking max token limit: {str(e)}")
#    1160 # MODEL CALL
# -> 1161 result = original_function(*args, **kwargs)
#    1162 end_time = datetime.datetime.now()
#    1163 if "stream" in kwargs and kwargs["stream"] is True:
#
# File ~/anaconda3/envs/Gen_AI/lib/python3.10/site-packages/litellm/main.py:3241, in completion(model, messages, timeout, temperature, top_p, n, stream, stream_options, stop, max_completion_tokens, max_tokens, modalities, prediction, audio, presence_penalty, frequency_penalty, logit_bias, user, reasoning_effort, response_format, seed, tools, tool_choice, logprobs, top_logprobs, parallel_tool_calls, web_search_options, deployment_id, extra_headers, functions, function_call, base_url, api_version, api_key, model_list, thinking, **kwargs)
#    3238     return response
#    3239 except Exception as e:
#    3240     ## Map to OpenAI Exception
# -> 3241     raise exception_type(
#    3242         model=model,
#    3243         custom_llm_provider=custom_llm_provider,
#    3244         original_exception=e,
#    3245         completion_kwargs=args,
#    3246         extra_kwargs=kwargs,
#    3247     )
#
# File ~/anaconda3/envs/Gen_AI/lib/python3.10/site-packages/litellm/litellm_core_utils/exception_mapping_utils.py:2239, in exception_type(model, original_exception, custom_llm_provider, completion_kwargs, extra_kwargs)
#    2237 if exception_mapping_worked:
#    2238     setattr(e, "litellm_response_headers", litellm_response_headers)
# -> 2239     raise e
#    2240 else:
#    2241     for error_type in litellm.LITELLM_EXCEPTION_TYPES:
#
# File ~/anaconda3/envs/Gen_AI/lib/python3.10/site-packages/litellm/litellm_core_utils/exception_mapping_utils.py:2208, in exception_type(model, original_exception, custom_llm_provider, completion_kwargs, extra_kwargs)
#    2206 exception_mapping_worked = True
#    2207 if hasattr(original_exception, "request"):
# -> 2208     raise APIConnectionError(
#    2209         message="{} - {}".format(exception_provider, error_str),
#    2210         llm_provider=custom_llm_provider,
#    2211         model=model,
#    2212         request=original_exception.request,
#    2213     )
#    2214 else:
#    2215     raise APIConnectionError(
#    2216         message="{}\n{}".format(
#    2217             str(original_exception), traceback.format_exc()
#    (...)
#    2223         ),  # stub the request
#    2224     )
#
# APIConnectionError: litellm.APIConnectionError: OllamaException - [Errno 111] Connection refused
